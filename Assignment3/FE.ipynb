# %% [markdown]
# # Karman Vortex street
#
# Mathematical model
# ---
#
# Navier Stokes Equations
#
# Find velocity $u : \Omega \times [0,T] \rightarrow R^d$ and pressure $p : \Omega \times [0,T] \rightarrow R$ such that
#
# $$
# \begin{array}{ccccl}
# \frac{\partial u}{\partial t} - \nu \Delta u + u \nabla u & + & \nabla p & = & f \\
# \operatorname{div} u & & & = & 0
# \end{array}
# $$
#
# Domain
# ---
# See Lecture09 slides for details.
#
# Numerical model
# ---
# Finite element method, mixed P3/P2 Taylor-Hood elements.
# Operator splitting in time-integration with the non-linear term explicit, but time-dependent Stokes fully implicit.
#
# The example is part of the ngsolve examples, and follows the setup from the Schäfer-Turek benchmark <http://www.mathematik.tu-dortmund.de/lsiii/cms/papers/SchaeferTurek1996.pdf> a two-dimensional cylinder, at Reynolds number 100

# %%
from ngsolve import *
from ngsolve.webgui import Draw
import ipywidgets as widgets

# %% [markdown]
# Schäfer-Turek benchmark geometry:

# %%
from netgen.occ import *

shape = Rectangle(2,0.41).Circle(0.2,0.2,0.05).Reverse().Face()
shape.edges.name="wall"
shape.edges.Min(X).name="inlet"
shape.edges.Max(X).name="outlet"
Draw (shape);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'ngsolve_version': 'Netgen x.x', 'mesh_dim': 3…

# %%
mesh = Mesh(OCCGeometry(shape, dim=2).GenerateMesh(maxh=0.07)).Curve(3)
Draw (mesh);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.26…

# %% [markdown]
# Higher order Taylor-Hood element pairing (P3/P2) for velocity and pressure:

# %%
V = VectorH1(mesh,order=3, dirichlet="wall|cyl|inlet")
Q = H1(mesh,order=2)
X = V*Q

u,p = X.TrialFunction()
v,q = X.TestFunction()

nu = 0.001  # viscosity
stokes = (nu*InnerProduct(grad(u), grad(v))+ \
    div(u)*q+div(v)*p - 1e-10*p*q)*dx

a = BilinearForm(stokes).Assemble()

# nothing here ...
f = LinearForm(X).Assemble()

# gridfunction for the solution
gfu = GridFunction(X)

D = 0.1
Re = 150  # Reynolds number value 
U = Re*nu/D

# %% [markdown]
# parabolic inflow at inlet:

# %%
uin = CoefficientFunction( (U*1.5*4*y*(0.41-y)/(0.41*0.41), 0) )
gfu.components[0].Set(uin, definedon=mesh.Boundaries("inlet"))
Draw (gfu.components[0], mesh, "vel");
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.26…

# %% [markdown]
# solve Stokes problem for initial conditions:

# %%
inv_stokes = a.mat.Inverse(X.FreeDofs())

res = f.vec - a.mat*gfu.vec
gfu.vec.data += inv_stokes * res

Draw (gfu.components[0], mesh);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.26…

# %% [markdown]
# implicit/explicit time-stepping:
#
# $$
# \frac{u_{n+1}-u_n}{\tau} - \nu \Delta u_{n+1} + \nabla p_{n+1} = f - u_n \nabla u_n
# $$
# and
# $$
# \operatorname{div} u_{n+1} = 0
# $$

# %%
tau = 1e-4 # timestep( 1e-5 for Re=200)

mstar = BilinearForm(u*v*dx+tau*stokes).Assemble()
inv = mstar.mat.Inverse(X.FreeDofs(), inverse="sparsecholesky")

# %% [markdown]
# the non-linear convective term $\int u \nabla u v$

# %%
conv = BilinearForm(X, nonassemble=True)
conv += (Grad(u) * u) * v * dx

# %% [markdown]
# implicit Euler/explicit Euler splitting method:

# %%
t = 0; i = 0
tend = 10
gfut = GridFunction(V, multidim=0)
vel = gfu.components[0]

scene = Draw (gfu.components[0], mesh,autoscale = True)
tw = widgets.Text(value='t = 0')
display(tw)

with TaskManager():
    while t < tend:
        res = conv.Apply(gfu.vec) + a.mat*gfu.vec
        gfu.vec.data -= tau * inv * res    

        t = t + tau; i = i + 1
        if i%10 == 0: scene.Redraw()
        if i%50 == 0: gfut.AddMultiDimComponent(vel.vec)
        if i%100 == 0: tw.value = "t = " + str(t)
    tw.value = "t = "+str(tend)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.26…
# Text(value='t = 0')

# %% [markdown]
# In the multidim - GridFunction gfut we have collected several time-steps, which can be animated now by the visualization:

# %%
Draw (gfut, mesh, interpolate_multidim=True, animate=True, autoscale = True);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.26…
